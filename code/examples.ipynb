# %%
print("start of the analysis")
# Out:
# start of the analysis

# %%
import os
import pandas as pd
import time

# %%
os.chdir(r"C:/BA_thesis/BA_v2_31.03")
print(f"working directory: {os.getcwd()}")
# Out:
# working directory: C:\BA_thesis\BA_v2_31.03

# %%
df = pd.read_pickle('files/checkpoints/top.pkl')
print(df.info())
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 30 entries, 236 to 230
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   clean_text             30 non-null     object
#  1   text                   30 non-null     object
#  2   semantic_id            30 non-null     object
#  3   date                   30 non-null     object
#  4   group                  30 non-null     object
#  5   vector                 30 non-null     object
#  6   Dim 1                  30 non-null     float32
#  7   Dim 2                  30 non-null     float32
#  8   hdbscan_labels         30 non-null     int64
#  9   hdbscan_probabilities  30 non-null     float64
#  10  outlier_scores_        30 non-null     float64
#  11  importance_measure     30 non-null     float64
# dtypes: float32(2), float64(3), int64(1), object(6)
# memory usage: 2.8+ KB
# None
#                                             clean_text  \
# ...

# %%
import spacy

# %%
grouped = df.groupby('hdbscan_labels')

with open('grupy.txt', 'w', encoding='utf-8') as f:
    for group_name, group_df in grouped:
        f.write('='*60 + f"Group: {group_name}" + '='*60 +'\n')
        for text in group_df['text']:
            f.write(text + "\n\n")
